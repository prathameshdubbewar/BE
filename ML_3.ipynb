# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
def f(x):
    return (x+3)**2

# %%
def df(x):
    return 2*x + 6

# %%
def gradient_descent(initial_x, learning_rate, num_iterations):
    x = initial_x
    x_history = [x]
    for i in range(num_iterations):
        gradient = df(x)
        x = x - learning_rate * gradient
        x_history.append(x)
    return x, x_history

# %%
initial_x = 2
learning_rate = 0.01
num_iterations = 90

x, x_history = gradient_descent(initial_x, learning_rate, num_iterations)
print("Local minimum: {:.2f}".format(x))
for i in range(len(x_history)):
    print(f"Iteration number {i}: {x_history[i]}")
# Out:
# Local minimum: -2.19
# Iteration number 0: 2
# Iteration number 1: 1.9
# Iteration number 2: 1.8019999999999998
# Iteration number 3: 1.70596
# Iteration number 4: 1.6118408
# Iteration number 5: 1.519603984
# Iteration number 6: 1.42921190432
# Iteration number 7: 1.3406276662336
# Iteration number 8: 1.253815112908928
# Iteration number 9: 1.1687388106507495
# Iteration number 10: 1.0853640344377344
# Iteration number 11: 1.0036567537489798
# Iteration number 12: 0.9235836186740002
# Iteration number 13: 0.8451119463005202
# Iteration number 14: 0.7682097073745098
# Iteration number 15: 0.6928455132270196
# Iteration number 16: 0.6189886029624792
# Iteration number 17: 0.5466088309032295
# Iteration number 18: 0.4756766542851649
# Iteration number 19: 0.40616312119946163
# Iteration number 20: 0.3380398587754724
# Iteration number 21: 0.27127906159996296
# Iteration number 22: 0.2058534803679637
# Iteration number 23: 0.14173641076060442
# Iteration number 24: 0.07890168254539233
# Iteration number 25: 0.017323648894484484
# Iteration number 26: -0.04302282408340521
# Iteration number 27: -0.10216236760173711
# Iteration number 28: -0.16011912024970237
# Iteration number 29: -0.21691673784470833
# Iteration number 30: -0.27257840308781417
# Iteration number 31: -0.3271268350260579
# Iteration number 32: -0.38058429832553675
# Iteration number 33: -0.432972612359026
# Iteration number 34: -0.4843131601118455
# Iteration number 35: -0.5346268969096086
# Iteration number 36: -0.5839343589714164
# Iteration number 37: -0.632255671791988
# Iteration number 38: -0.6796105583561483
# Iteration number 39: -0.7260183471890252
# Iteration number 40: -0.7714979802452447
# Iteration number 41: -0.8160680206403399
# Iteration number 42: -0.8597466602275331
# Iteration number 43: -0.9025517270229825
# Iteration number 44: -0.9445006924825228
# Iteration number 45: -0.9856106786328723
# Iteration number 46: -1.025898465060215
# Iteration number 47: -1.0653804957590107
# Iteration number 48: -1.1040728858438305
# Iteration number 49: -1.1419914281269539
# Iteration number 50: -1.1791515995644148
# Iteration number 51: -1.2155685675731265
# Iteration number 52: -1.2512571962216639
# Iteration number 53: -1.2862320522972306
# Iteration number 54: -1.320507411251286
# Iteration number 55: -1.3540972630262602
# Iteration number 56: -1.387015317765735
# Iteration number 57: -1.4192750114104202
# Iteration number 58: -1.4508895111822118
# Iteration number 59: -1.4818717209585675
# Iteration number 60: -1.512234286539396
# Iteration number 61: -1.5419896008086083
# Iteration number 62: -1.571149808792436
# Iteration number 63: -1.5997268126165873
# Iteration number 64: -1.6277322763642557
# Iteration number 65: -1.6551776308369706
# Iteration number 66: -1.6820740782202313
# Iteration number 67: -1.7084325966558267
# Iteration number 68: -1.7342639447227102
# Iteration number 69: -1.759578665828256
# Iteration number 70: -1.784387092511691
# Iteration number 71: -1.808699350661457
# Iteration number 72: -1.832525363648228
# Iteration number 73: -1.8558748563752634
# Iteration number 74: -1.8787573592477582
# Iteration number 75: -1.901182212062803
# Iteration number 76: -1.923158567821547
# Iteration number 77: -1.9446953964651161
# Iteration number 78: -1.9658014885358137
# Iteration number 79: -1.9864854587650975
# Iteration number 80: -2.0067557495897956
# Iteration number 81: -2.026620634598
# Iteration number 82: -2.04608822190604
# Iteration number 83: -2.065166457467919
# Iteration number 84: -2.0838631283185607
# Iteration number 85: -2.1021858657521895
# Iteration number 86: -2.1201421484371457
# Iteration number 87: -2.137739305468403
# Iteration number 88: -2.1549845193590347
# Iteration number 89: -2.171884828971854
# Iteration number 90: -2.188447132392417

# %%
x_vals = np.linspace(-11, 5, 5000)
plt.plot(x_vals, f(x_vals))
plt.plot(x_history, f(np.array(x_history)), 'rx')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %%
x_vals = np.linspace(-11, 5, 50)
plt.plot(x_vals, f(x_vals))
plt.plot(x_history, f(np.array(x_history)), 'rx')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()
